# %% [markdown]
# # Naive Bayes

# %% [markdown]
# #### Gaussian Naive Bayes on Continuous Data
# ##### Dataset: from sklearn.datasets import load_iris
# ##### Task: Load a dataset with continuous numerical features (e.g., the Iris dataset).
# ##### Action: Train a Gaussian Naive Bayes classifier (which assumes features follow a normal distribution). Make predictions and output the classification accuracy.

# %%
from sklearn.datasets import load_iris
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

X, y = load_iris(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

clf = GaussianNB()
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

print(f"Accuracy: {accuracy_score(y_test, y_pred):.4f}")
print()
print(classification_report(y_test, y_pred, target_names=load_iris().target_names))
# Out:
# Accuracy: 0.9778
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        19
#   versicolor       1.00      0.92      0.96        13
#    virginica       0.93      1.00      0.96        13
#
#     accuracy                           0.98        45
#    macro avg       0.98      0.97      0.97        45
# weighted avg       0.98      0.98      0.98        45

# %% [markdown]
# #### Text Classification with Multinomial Naive Bayes
# ##### Dataset: Spam SMS
# ##### Task: Download a Spam vs. Ham SMS dataset.
# ##### Action: Preprocess the text data using a CountVectorizer or TfidfVectorizer to convert the text into numerical word frequencies. Train a Multinomial Naive Bayes classifier on this vectorized data to predict whether a new message is Spam or Ham.

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score

df = pd.read_csv('spam_sms.csv')

vec = TfidfVectorizer(stop_words='english')
clf = MultinomialNB()
clf.fit(vec.fit_transform(df['message']), df['label'])

preds = clf.predict(vec.transform(df['message']))
print(f"Accuracy: {accuracy_score(df['label'], preds):.4f}\n")
for msg, pred in zip(df['message'], preds):
    print(f"[{pred.upper():4s}]  {msg}")
# Out:
# Accuracy: 1.0000
#
# [HAM ]  Hey, are we still on for dinner tonight?
# [SPAM]  WINNER!! Claim your free iPhone now by clicking this link!
# [HAM ]  Don't forget to bring the documents to the meeting.
# [SPAM]  URGENT: Your bank account has been locked. Reply with your PIN to unlock.
# [HAM ]  Can you pick up some milk on your way home?
# [SPAM]  Congratulations! You've been selected for a $1000 Walmart gift card.
# [HAM ]  Let me know when you arrive safely.
# [SPAM]  Get cheap loans instantly! No credit check required. Text LOAN to 55555.
